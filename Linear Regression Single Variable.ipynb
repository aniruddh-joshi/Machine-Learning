# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv(r'C:\Users\nj\Downloads\insurance.csv')
df
# Out:
#    age  premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    65000

# %%
sns.lmplot(x='age',y='premium',data=df)

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['age']],df['premium'])
# Out:
# LinearRegression()

# %%
reg.predict([[21]])
# Out:
# C:\Users\nj\Documents\ml-course\env\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9880.])

# %%
reg.predict([[50]])
# Out:
# C:\Users\nj\Documents\ml-course\env\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([73100.])

# %%
reg.coef_
# Out:
# array([2180.])

# %%
reg.intercept_
# Out:
# -35900.0
